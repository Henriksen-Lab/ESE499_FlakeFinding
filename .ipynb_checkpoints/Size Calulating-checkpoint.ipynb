# %% [markdown]
# ## Size Calculating ##
#
# Approach:
# 1. Threshold
# 2. FindContours
# 3. ContourArea?

# %%
# import python packages
import cv2
import numpy as np
import math
from scipy.spatial import distance as dist
from imutils import perspective
from imutils import contours
import numpy as np
import argparse
import imutils
import cv2
#from matplotlib import pyplot as plt
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Input In [15], in <cell line: 5>()
#       3 import numpy as np
#       4 import math
# ----> 5 from scipy.spatial import distance as dist
#       6 from imutils import perspective
#       7 from imutils import contours
#
# ModuleNotFoundError: No module named 'scipy'

# %%
# import & display photos
img1 = cv2.imread("Images/Feasibility Study/blocks.jpg")
hsv = cv2.cvtColor(img1, cv2.COLOR_BGR2HSV)

# %% [markdown]
# ## Original Blocks Image
# ![blocks.jpg](attachment:blocks.jpg)

# %% [markdown]
# ## Edge Detection Using Canny

# %%
# Edge Detection using canny
edge_img = cv2.imread("Images/Feasibility Study/shapes-01.jpg")
scale_percent = 40 # percent of original size
width = int(edge_img.shape[1] * scale_percent / 100)
height = int(edge_img.shape[0] * scale_percent / 100)
dim = (width, height)
resized = cv2.resize(edge_img, dim, interpolation = cv2.INTER_AREA)

# %%
#convert image to grayscale and blur image
edge_gray = cv2.cvtColor(resized, cv2.COLOR_BGR2GRAY)
edge_blur = cv2.GaussianBlur(edge_gray, (3,3), 0)

# Canny Edge Detection
edges = cv2.Canny(image=edge_blur, threshold1=100, threshold2=200) # Canny Edge Detection
cv2.imwrite('Images/Feasibility Study/edges.jpg', edges)
# Out:
# True

# %% [markdown]
# ![edges.jpg](attachment:edges.jpg)

# %%
bl_a_50x = cv2.imread("Images/GRAPENE/bl_1/bl_a_50x.jpg")
# convert to grayscale & blur slightly
gray = cv2.cvtColor(bl_a_50x, cv2.COLORBGR2GRAY)
gray = cv2.GaussianBlur(gray, (7,7), 0)

bl_a_50x_blur = cv2.Canny(gray, 50, 100)

cnts = cv2.findContours
# Out:
# [ WARN:0@28.592] global /Users/runner/work/opencv-python/opencv-python/opencv/modules/imgcodecs/src/loadsave.cpp (239) findDecoder imread_('Images/GRAPENE/bl_1/bl_a_50x.jpg'): can't open/read file: check file path/integrity

# %% [markdown]
# ![bl_a_50x.jpg](attachment:bl_a_50x.jpg)

# %%
thresh1 = cv2.threshold(bl_a_50x,10,10,255,cv2.THRESH_BINARY)[1]
cv2.imwrite("Images/bl_a_50x_thresh.jpg", thresh1)
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Input In [13], in <cell line: 2>()
#       1 thresh1 = cv2.threshold(bl_a_50x,10,10,255,cv2.THRESH_BINARY)[1]
# ----> 2 cv2.imwrite("bl_a_50x_thresh.jpg", thresh1)
#
# error: OpenCV(4.6.0) /Users/runner/work/opencv-python/opencv-python/opencv/modules/imgcodecs/src/loadsave.cpp:801: error: (-215:Assertion failed) !_img.empty() in function 'imwrite'
